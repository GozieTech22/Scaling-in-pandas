# %%
import pandas as pd
import numpy as np

# %%
fg = pd.read_csv("day_wise.csv")

# %%
fg.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
fg.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# ...

# %%
min_ = fg.Deaths.min()
max_ = fg.Deaths.max()

# %%
 min_
# Out:
# 17

# %%
max_
# Out:
# 654036

# %% [markdown]
# ## Absolute Max scaling

# %%
(fg.Deaths/max_)
# Out:
# 0      0.000026
# 1      0.000028
# 2      0.000040
# 3      0.000064
# 4      0.000086
# 5      0.000125
# 6      0.000200
# 7      0.000203
# 8      0.000261
# 9      0.000326
# 10     0.000396
# 11     0.000553
# 12     0.000651
# 13     0.000752
# 14     0.000862
# 15     0.000969
# 16     0.001099
# 17     0.001232
# 18     0.001385
# 19     0.001549
# 20     0.001702
# 21     0.001709
# 22     0.002096
# 23     0.002329
# 24     0.002547
# 25     0.002706
# 26     0.002856
# 27     0.003070
# 28     0.003246
# 29     0.003434
#          ...
# 158    0.768088
# 159    0.773777
# 160    0.781624
# 161    0.789285
# 162    0.797114
# 163    0.804751
# 164    0.811431
# 165    0.816698
# 166    0.822504
# 167    0.831841
# 168    0.839974
# 169    0.848319
# 170    0.856439
# 171    0.863926
# 172    0.869972
# 173    0.875805
# 174    0.884459
# 175    0.892858
# 176    0.901724
# 177    0.912034
# 178    0.920637
# 179    0.926798
# 180    0.933158
# 181    0.942696
# ...

# %%
fg["Deaths_Scaled"]=(fg.Deaths/max_)

# %%
fg.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries  DEaths_Scaled  Deaths_Scaled
# 0                   60.71                 6       0.000026       0.000026
# ...

# %%
fg.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# ...

# %%
fg.Deaths_Scaled.plot()

# %%
fg.Deaths.plot()

# %% [markdown]
# ## Robust Scaling

# %%
fg.describe(percentiles = [0.1,0.2,0.3])
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 10%    4.187160e+04     980.900000  3.516900e+03  3.737380e+04    1858.400000
# 20%    8.416900e+04    2894.600000  3.650920e+04  5.247000e+04    3308.200000
# 30%    2.211348e+05    8955.600000  8.159070e+04  1.305885e+05   20419.200000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# ...

# %%
fg.describe(percentiles = [0.1,0.2,0.3])["Deaths"]
# Out:
# count       188.000000
# mean     230770.760638
# std      217929.094183
# min          17.000000
# 10%         980.900000
# 20%        2894.600000
# 30%        8955.600000
# 50%      204190.000000
# max      654036.000000
# Name: Deaths, dtype: float64

# %%
fg.describe(percentiles=[0.1,0.2,0.3], include=None, exclude=None)
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 10%    4.187160e+04     980.900000  3.516900e+03  3.737380e+04    1858.400000
# 20%    8.416900e+04    2894.600000  3.650920e+04  5.247000e+04    3308.200000
# 30%    2.211348e+05    8955.600000  8.159070e+04  1.305885e+05   20419.200000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# ...

# %%
First_Quan = 980.900000
Second_Quan = 2894.600000
Third_Quan = 8955.600000

# %%
(fg.Deaths-First_Quan)/(Third_Quan-First_Quan)
# Out:
# 0      -0.120870
# 1      -0.120744
# 2      -0.119741
# 3      -0.117735
# 4      -0.115979
# 5      -0.112719
# 6      -0.106575
# 7      -0.106324
# 8      -0.101559
# 9      -0.096292
# 10     -0.090524
# 11     -0.077608
# 12     -0.069583
# 13     -0.061306
# 14     -0.052278
# 15     -0.043500
# 16     -0.032841
# 17     -0.021932
# 18     -0.009392
# 19      0.004025
# 20      0.016565
# 21      0.017192
# 22      0.048917
# 23      0.067977
# 24      0.085909
# 25      0.098950
# 26      0.111239
# 27      0.128795
# 28      0.143215
# 29      0.158639
#          ...
# 158    62.870842
# 159    63.337442
# 160    63.980977
# 161    64.609340
# 162    65.251370
# 163    65.877726
# 164    66.425583
# 165    66.857575
# 166    67.333705
# 167    68.099502
# 168    68.766487
# 169    69.450901
# 170    70.116882
# 171    70.730949
# 172    71.226767
# 173    71.705155
# 174    72.414900
# 175    73.103703
# 176    73.830878
# 177    74.676427
# 178    75.382033
# ...

# %%
fg["R_Scaled_Deaths"]=(fg.Deaths-First_Quan)/(Third_Quan-First_Quan)

# %%
fg.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries  DEaths_Scaled  Deaths_Scaled  \
# 0                   60.71                 6       0.000026       0.000026
# ...

# %%
fg.R_Scaled_Deaths.plot()

# %%
fg.	Deaths_Scaled.plot()
